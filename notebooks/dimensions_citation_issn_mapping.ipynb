# %%
__author__ = "Jon Ball"
__version__ = "June 2024"

# %%
import re
import json
import numpy as np
import pandas as pd
import networkx as nx
from scipy import stats
from collections import defaultdict
from numpy import array # needed for eval()

# %%
with open("data/issns_active_2022.txt", "r") as infile:
    issnsActive = list(line.strip() for line in infile.readlines())
issnsActive = {issn: 1 for issn in issnsActive if issn}
print(len(issnsActive))
# Out:
# 60709

# %%
def get_edges(row):
    # for each unique publication in the dimensions data
    pub_id = row["publication_id"]
    # if the ISSN indicates a 2022 active OJS context
    if row["issn"] in issnsActive or row["eissn"] in issnsActive:
        # get publication_id for each document it references
        ref_ids =  list(set([s.strip("'") for s in row["reference_ids"].strip("[]").split()])) if "[]" not in row["reference_ids"] else []
        # get publication_id for each document that cites it
        cite_ids = list(set([d["id"] for d in [eval(s) for s in re.split(r"\.*\n+\.*", row["citing_ids"].strip("[]"))]])) if "[]" not in row["citing_ids"] else []
        # define edges in the citation graph
        V = [(pub_id, ref_id) for ref_id in ref_ids if ref_id]
        V += [(cite_id, pub_id) for cite_id in cite_ids if cite_id]
        return V
    else:
        return None

# %%
def get_issns(row):
    # if an ISSN is provided
    issn = row["issn"]
    issn = issn.strip() if isinstance(issn, str) else ""
    # if an E-ISSN is provided
    eissn = row["eissn"]
    eissn = eissn.strip() if isinstance(eissn, str) else ""
    # join ISSN and E-ISSN if both are present, else take either
    if issn and eissn:
        issns = f"{issn}\n{eissn}"
    elif issn:
        issns = issn
    elif eissn:
        issns = eissn
    else:
        issns = None
    return issns

# %%
def get_id_issn_map(row):
    # for each unique publication in the dimensions data
    pub_id = row["publication_id"]
    # return a mapping of publication_id to ISSN(s)
    issns = row["issns"]
    return pub_id, issns

# %%
def get_field_specific_issns(df, field):
    mask = (df["category_for"].notnull()) & (df["category_for"].str.contains(field))
    issns = set(df[mask]["issn"].dropna()) | set(df[mask]["eissn"].dropna())
    return issns

# %%
fields = {
    "agriculture": "Agricultural, Veterinary and Food Sciences",
    "bio": "Biological Sciences",
    "biomed": "Biomedical and Clinical Sciences",
    "design": "Built Environment and Design",
    "chem": "Chemical Sciences",
    "commerce": "Commerce, Management, Tourism and Services",
    "art": "Creative Arts and Writing",
    "earth": "Earth Sciences",
    "econ": "Economics",
    "ed": "Education",
    "engineering": "Engineering",
    "envisci": "Environmental Sciences",
    "health": "Health Sciences",
    "hist": "History, Heritage AND Archaeology",
    "soc": "Human Society",
    "indig": "Indigenous Studies",
    "infocomp": "Information and Computing Sciences",
    "comm": "Language, Communication and Culture",
    "law": "Law and Legal Studies",
    "math": "Mathematical Sciences",
    "phil": "Philosophy and Religious Studies",
    "phys": "Physical Sciences",
    "psych": "Psychology"  
}

# %% [markdown]
# ## references_of_all_pubs.csv - 2022 active ISSNs

# %%
ref_df = pd.read_csv("data/references_of_all_pubs.csv", header=None)
ref_df.columns = ["index", "publication_id", "reference_ids", "citing_ids", "doi", "issn", "eissn", "type", "date", "category_for", "times_cited", "research_org_cities", "ur_id", "source", "research_org_country_names", "altmetrics", "title", "abstract", "concepts", "idk"]
ref_df["issns"] = ref_df.apply(get_issns, axis=1)
ref_df.head()
# Out:
#    index  publication_id                                      reference_ids  \
# 0      0  pub.1120627557                                                 []
# 1      1  pub.1016805418  ['pub.1060450759' 'pub.1060527901' 'pub.106052...
# 2      2  pub.1144573636  ['pub.1029003997' 'pub.1134779582' 'pub.113470...
# 3      3  pub.1142327767  ['pub.1001503523' 'pub.1002062994' 'pub.100313...
# 4      4  pub.1037712872  ['pub.1069651355' 'pub.1058573268' 'pub.100770...
#
#                                           citing_ids  \
# 0           [{'id': 'pub.1158208917', 'year': 2023}]
# 1  [{'id': 'pub.1138140594', 'year': 2021}\n {'id...
# 2  [{'id': 'pub.1162918892', 'year': 2023}\n {'id...
# 3  [{'id': 'pub.1150797038', 'year': 2022}\n {'id...
# 4  [{'id': 'pub.1134429328', 'year': 2021}\n {'id...
#
#                             doi       issn      eissn     type        date  \
# 0       10.35673/ajmpi.v4i1.215  2406-8802  2685-550X  article  2019-07-31
# 1              10.1038/294139a0  0028-0836  1476-4687  article  1981-11-01
# 2             10.3390/w14020151        NaN  2073-4441  article  2022-01-07
# 3    10.1016/j.seta.2021.101661  2213-1388  2213-1396  article  2022-02-01
# 4  10.1016/0304-3878(81)90004-3  0304-3878  1872-6089  article  1981-08-01
#
#                                         category_for  ...  \
# 0  {'first_level': {'codes': array(['43', '50'], ...  ...
# 1  {'first_level': {'codes': array(['34', '51'], ...  ...
# 2  {'first_level': {'codes': array(['37', '40'], ...  ...
# 3  {'first_level': {'codes': array(['33'], dtype=...  ...
# 4  {'first_level': {'codes': array(['38', '44'], ...  ...
#
#              research_org_cities  \
# 0                             []
# 1              ['grid.482271.a']
# 2                             []
# 3  ['grid.1004.5' 'grid.5037.1']
# 4              ['grid.17635.36']
#
#                                                ur_id  \
# 0                             ['ur.011573102374.79']
# 1  ['ur.0770644175.43' 'ur.01133403503.58' 'ur.01...
# 2  ['ur.011257637763.81' 'ur.016141117352.37' 'ur...
# 3         ['ur.011201747573.76' 'ur.01166110143.28']
# 4        ['ur.010256274757.27' 'ur.012552575265.02']
#
#                                               source  \
# 0  {'id': 'jour.1377569', 'title': 'Al-Adalah Jur...
# 1  {'id': 'jour.1018957', 'title': 'Nature', 'iss...
# 2  {'id': 'jour.1398516', 'title': 'Water', 'issn...
# 3  {'id': 'jour.1144532', 'title': 'Sustainable E...
# 4  {'id': 'jour.1122871', 'title': 'Journal of De...
#
#   research_org_country_names                       altmetrics  \
# 0                         []      {'id': None, 'score': None}
# 1         ['United Kingdom']      {'id': None, 'score': None}
# 2                         []      {'id': None, 'score': None}
# 3     ['Australia' 'Sweden']  {'id': '119980489', 'score': 8}
# 4          ['United States']  {'id': '64389583', 'score': 15}
#
#                                                title  \
# 0  {'preferred': 'PRAKSIS POLITIK NABI MUHAMMAD S...
# 1  {'preferred': 'Near-edge X-ray absorption spec...
# 2  {'preferred': 'Development of a Distributed Ma...
# 3  {'preferred': 'A comparative review on the app...
# 4  {'preferred': 'The measurement and sources of ...
#
#                                             abstract  \
# 0  {'preferred': "This paper examines the praxis ...
# 1  {'preferred': 'The measurement of X-ray absorp...
# 2  {'preferred': 'The article is devoted to the p...
# 3  {'preferred': 'Radiant low-temperature heating...
# 4  {'preferred': 'Production function models are ...
#
#                                             concepts idk                 issns
# 0  [{'concept': 'political action', 'relevance': ...  []  2406-8802\n2685-550X
# 1  [{'concept': 'X-ray absorption fine structure'...  []  0028-0836\n1476-4687
# 2  [{'concept': 'mathematical model', 'relevance'...  []             2073-4441
# 3  [{'concept': 'high-temperature cooling', 'rele...  []  2213-1388\n2213-1396
# 4  [{'concept': 'firm attributes', 'relevance': 0...  []  0304-3878\n1872-6089
#
# [5 rows x 21 columns]

# %%
activeDF = ref_df[(ref_df["issn"].isin(issnsActive.keys())) | (ref_df["eissn"].isin(issnsActive.keys()))].copy()
activeDF.count()
# Out:
# index                         1215121
# publication_id                1215121
# reference_ids                 1215121
# citing_ids                    1215121
# doi                           1187300
# issn                          1077002
# eissn                         1119079
# type                          1215121
# date                          1214844
# category_for                   797000
# times_cited                   1215107
# research_org_cities           1215121
# ur_id                         1215121
# source                        1215121
# research_org_country_names    1215121
# altmetrics                    1215121
# title                         1215121
# abstract                      1005616
# concepts                      1215121
# idk                           1215121
# issns                         1215121
# dtype: int64

# %%
activeDF["edges"] = activeDF.apply(get_edges, axis=1)
print(activeDF.iloc[0]["edges"])
# Out:
# [('pub.1158208917', 'pub.1120627557')]

# %%
edge_list = [e for el in activeDF["edges"].tolist() for e in el]
print(len(edge_list))
print(edge_list[0])
# Out:
# 39646526
# ('pub.1158208917', 'pub.1120627557')

# %%
unique_contexts = activeDF[activeDF["issns"].notnull()]["issns"].unique().tolist()
print(len(unique_contexts))
# Out:
# 24309

# %%
id2issns = ref_df.apply(get_id_issn_map, axis=1).tolist()
print(id2issns[0])
# Out:
# ('pub.1120627557', '2406-8802\n2685-550X')

# %%
field_issns = {field: get_field_specific_issns(ref_df, pattern) for field, pattern in fields.items()}
del ref_df

# %% [markdown]
# ## citations_of_all_pubs.csv - 2022 active ISSNs

# %%
cite_df = pd.read_csv("data/citations_of_all_pubs.csv", header=None)
cite_df.columns = ["index", "publication_id", "reference_ids", "citing_ids", "doi", "issn", "eissn", "type", "date", "category_for", "times_cited", "research_org_cities", "ur_id", "source", "research_org_country_names", "altmetrics", "title", "abstract", "concepts"]
cite_df["issns"] = cite_df.apply(get_issns, axis=1)
cite_df.head()
# Out:
#    index  publication_id                                      reference_ids  \
# 0      0  pub.1011627231  ['pub.1000621744' 'pub.1000722723' 'pub.100103...
# 1      1  pub.1011182182  ['pub.1013726283' 'pub.1018900088' 'pub.102673...
# 2      2  pub.1000357800  ['pub.1008741958' 'pub.1040358033' 'pub.105278...
# 3      3  pub.1007126901  ['pub.1006612903' 'pub.1010028023' 'pub.100433...
# 4      4  pub.1007032109  ['pub.1102845096' 'pub.1113140804' 'pub.106505...
#
#                                           citing_ids  \
# 0  [{'id': 'pub.1115166073', 'year': 2016}\n {'id...
# 1  [{'id': 'pub.1102285413', 'year': 2010}\n {'id...
# 2  [{'id': 'pub.1055082006', 'year': 2015}\n {'id...
# 3  [{'id': 'pub.1035493063', 'year': 2009}\n {'id...
# 4  [{'id': 'pub.1046862372', 'year': 2015}\n {'id...
#
#                               doi       issn      eissn     type        date  \
# 0      10.1152/ajpendo.90306.2008  0193-1849  1522-1555  article  2008-05-20
# 1              10.1353/apa.0.0007  0360-5949  1533-0699  article  2008-03-01
# 2  10.1016/j.cryobiol.2008.09.005  0011-2240  1090-2392  article  2008-09-19
# 3  10.1080/02513625.2008.10557013  0251-3625  2166-8604  article  2008-01-01
# 4       10.1080/14623940701816709  1462-3943  1470-1103  article  2008-02-01
#
#                                         category_for  \
# 0  {'first_level': {'codes': array(['31', '42'], ...
# 1  {'first_level': {'codes': array(['43', '44', '...
# 2  {'first_level': {'codes': array(['30', '32'], ...
# 3  {'first_level': {'codes': array(['33'], dtype=...
# 4  {'first_level': {'codes': array(['50'], dtype=...
#
#                                          times_cited research_org_cities  \
# 0  {'times_cited': 100, 'recent_citations': 6, 'f...     ['grid.6451.6']
# 1  {'times_cited': 7, 'recent_citations': 2, 'fie...   ['grid.266515.3']
# 2  {'times_cited': 29, 'recent_citations': 1, 'fi...   ['grid.29980.3a']
# 3  {'times_cited': 2, 'recent_citations': 0, 'fie...                  []
# 4  {'times_cited': 3, 'recent_citations': 0, 'fie...   ['grid.410319.e']
#
#                                                ur_id  \
# 0          ['ur.07527627403.94' 'ur.01276472107.59']
# 1                             ['ur.011637600145.05']
# 2  ['ur.013616340112.49' 'ur.01310020772.09' 'ur....
# 3        ['ur.016213633215.53' 'ur.016420304310.79']
# 4                              ['ur.01313550775.24']
#
#                                               source  \
# 0  {'id': 'jour.1327387', 'title': 'AJP Endocrino...
# 1  {'id': 'jour.1143161', 'title': 'Transactions ...
# 2  {'id': 'jour.1001351', 'title': 'Cryobiology',...
# 3  {'id': 'jour.1053460', 'title': 'disP - The Pl...
# 4  {'id': 'jour.1139399', 'title': 'Reflective Pr...
#
#   research_org_country_names                      altmetrics  \
# 0                 ['Israel']     {'id': None, 'score': None}
# 1          ['United States']  {'id': '56626804', 'score': 9}
# 2            ['New Zealand']     {'id': None, 'score': None}
# 3                         []     {'id': None, 'score': None}
# 4                 ['Canada']     {'id': None, 'score': None}
#
#                                                title  \
# 0  {'preferred': 'Transcriptional regulation of t...
# 1  {'preferred': 'Genus quid est?: Roman Scholars...
# 2  {'preferred': 'Characterization of a family of...
# 3  {'preferred': 'Die Zentralität war schon da!',...
# 4  {'preferred': 'Performing responsibility: ethi...
#
#                                             abstract concepts  \
# 0  {'preferred': 'The insulin-responsive glucose ...       []
# 1  {'preferred': 'From at least as early as Varro...       []
# 2  {'preferred': 'Five genes coding for ice-activ...       []
# 3                                                NaN       []
# 4  {'preferred': 'I explore, and reflect on, the ...       []
#
#                   issns
# 0  0193-1849\n1522-1555
# 1  0360-5949\n1533-0699
# 2  0011-2240\n1090-2392
# 3  0251-3625\n2166-8604
# 4  1462-3943\n1470-1103

# %%
activeDF = cite_df[(cite_df["issn"].isin(issnsActive.keys())) | (cite_df["eissn"].isin(issnsActive.keys()))].copy()
activeDF.count()
# Out:
# index                         992926
# publication_id                992926
# reference_ids                 992926
# citing_ids                    992926
# doi                           987473
# issn                          869269
# eissn                         926256
# type                          992926
# date                          992414
# category_for                  746954
# times_cited                   992918
# research_org_cities           992926
# ur_id                         992926
# source                        992926
# research_org_country_names    992926
# altmetrics                    992926
# title                         992926
# abstract                      889261
# concepts                      992926
# issns                         992926
# dtype: int64

# %%
unique_contexts += activeDF[activeDF["issns"].notnull()]["issns"].unique().tolist()
print(len(unique_contexts))
# Out:
# 37575

# %%
activeDF["edges"] = activeDF.apply(get_edges, axis=1)
print(activeDF.iloc[0]["edges"])
# Out:
# [('pub.1034132371', 'pub.1022711941'), ('pub.1034132371', 'pub.1002326098'), ('pub.1034132371', 'pub.1052271780'), ('pub.1034132371', 'pub.1026913579'), ('pub.1034132371', 'pub.1003604100'), ('pub.1034132371', 'pub.1045799580'), ('pub.1043886108', 'pub.1034132371'), ('pub.1019258875', 'pub.1034132371'), ('pub.1017412483', 'pub.1034132371'), ('pub.1031903195', 'pub.1034132371'), ('pub.1080561215', 'pub.1034132371'), ('pub.1020250538', 'pub.1034132371'), ('pub.1020310430', 'pub.1034132371'), ('pub.1045952946', 'pub.1034132371'), ('pub.1032937461', 'pub.1034132371'), ('pub.1022062989', 'pub.1034132371'), ('pub.1082366114', 'pub.1034132371'), ('pub.1008432868', 'pub.1034132371'), ('pub.1039318119', 'pub.1034132371'), ('pub.1081321795', 'pub.1034132371'), ('pub.1020675711', 'pub.1034132371'), ('pub.1000087098', 'pub.1034132371'), ('pub.1043495094', 'pub.1034132371'), ('pub.1012545893', 'pub.1034132371'), ('pub.1081150687', 'pub.1034132371'), ('pub.1008448320', 'pub.1034132371'), ('pub.1028685680', 'pub.1034132371'), ('pub.1021686121', 'pub.1034132371'), ('pub.1048157150', 'pub.1034132371'), ('pub.1017860117', 'pub.1034132371'), ('pub.1041770623', 'pub.1034132371'), ('pub.1001087675', 'pub.1034132371'), ('pub.1093077033', 'pub.1034132371'), ('pub.1081042789', 'pub.1034132371'), ('pub.1015365449', 'pub.1034132371'), ('pub.1067818797', 'pub.1034132371'), ('pub.1079673138', 'pub.1034132371')]

# %%
edge_list += [e for el in activeDF["edges"].tolist() for e in el]
print(len(edge_list))
print(edge_list[-1])
# Out:
# 78578459
# ('pub.1140573500', 'pub.1058345146')

# %%
id2issns += cite_df.apply(get_id_issn_map, axis=1).tolist()
print(id2issns[-1])
# Out:
# ('pub.1032068684', '0001-8791\n1095-9084')

# %%
for field, pattern in fields.items():
    field_issns[field] |= get_field_specific_issns(cite_df, pattern)
# Save the field-specific ISSN sets
with open("data/field_issns.json", "w") as outfile:
    json.dump({k: list(v) for k, v in field_issns.items()}, outfile)

# %%
del cite_df

# %% [markdown]
# ## Map publication_id's to ISSNs in the citation graph

# %%
id2issns_dict = dict(id2issns)
issnEdges = defaultdict(list)
for citer_id, citee_id in edge_list:
    try:
        issnEdges[id2issns_dict[citer_id]].append(id2issns_dict[citee_id])
    except KeyError:
        continue
print(len(issnEdges))
# Out:
# 57006

# %%
print(len(issnEdges))
# Out:
# 57006

# %%
with open("data/issnEdges.json", "w") as outfile:
    json.dump(issnEdges, outfile)

# %%
with open("data/unique_contexts.json", "w") as outfile:
    json.dump(unique_contexts, outfile)

# %% [markdown]
# ## Calculate a ratio of within-OJS citations and references, to out-citations and references, in the citation graph

# %%
import json
import numpy as np
import pandas as pd
import networkx as nx
from scipy import stats
from collections import deque

# %%
def is_publisher_journal(issn, issn_lookup):
    if issn is None:
        return False
    if isinstance(issn, str):
        if issn in issn_lookup:
            return True
        if "\n" in issn:
            return any(i in issn_lookup for i in issn.split("\n"))
    return False

# %%
# Load the ISSN edges dictionary
with open("data/issnEdges.json", "r") as f:
    issnEdges = json.load(f)
print(len(issnEdges))
# Out:
# 57006

# %%
# Load the list of publisher ISSNs
with open("data/issns_active_2022.txt", "r") as f:
    publisher_issns = set(line.strip() for line in f)
print(len(publisher_issns))
# Out:
# 60709

# %%
# Create a lookup set for faster membership testing
publisher_issn_lookup = set()
for issn in publisher_issns:
    publisher_issn_lookup.add(issn)
    if "\n" in issn:
        publisher_issn_lookup.update(issn.split("\n"))
print(len(publisher_issn_lookup))
# Out:
# 60709

# %%
# Load the field-specific ISSN sets
with open("data/field_issns.json", "r") as f:
    field_issns = {k: set(v) for k, v in json.load(f).items()}
for field in field_issns:
    print(f"{field}: {len(field_issns[field])}")
# Out:
# agriculture: 23304
# bio: 29346
# biomed: 40839
# design: 16981
# chem: 14367
# commerce: 36349
# art: 21390
# earth: 18827
# econ: 17338
# ed: 33035
# engineering: 34164
# envisci: 17960
# health: 31736
# hist: 0
# soc: 43902
# indig: 0
# infocomp: 35852
# comm: 30551
# law: 24092
# math: 12319
# phil: 32670
# phys: 10944
# psych: 21045

# %%
# Load Indonesian IDs
with open("data/beacon.csv", "r") as infile:
    beacon = pd.read_csv(infile)
beaconID = beacon[(beacon["record_count_2022"] >= 5) &
                  (beacon["country_tld"].notnull()) & 
                  (beacon["country_tld"].str.contains("ID"))]
issnsID = beaconID[beaconID["issn"].notnull()].issn.tolist()
issnsID = set([sub for issn in issnsID for sub in issn.split("\n") if sub])
print(len(issnsID))
# Out:
# 26102

# %%
def build_citation_graph(issnEdges):
    G = nx.DiGraph()
    for citing_journal, cited_journals in issnEdges.items():
        if citing_journal is not None:
            for cited_journal in cited_journals:
                if cited_journal is not None:
                    G.add_edge(citing_journal, cited_journal)
    return G

# %%
def get_top_central_journals(G, issn_set, top_n=50):
    # Calculate in-degree and out-degree centrality
    in_degree = nx.in_degree_centrality(G)
    out_degree = nx.out_degree_centrality(G)
    
    # Combine in-degree and out-degree
    total_degree = {node: in_degree.get(node, 0) + out_degree.get(node, 0) 
                    for node in set(in_degree) | set(out_degree)}
    
    # Filter for journals in the given ISSN set
    filtered_degree = {k: v for k, v in total_degree.items() if k is not None and is_publisher_journal(k, issn_set)}
    
    # Sort and return top N journals
    top_journals = sorted(filtered_degree.items(), key=lambda x: x[1], reverse=True)[:top_n]
    return top_journals

# %%
def calculate_ratios(issn_set, name, field_issns=None):
    confidence = 0.95
    internal_citations = 0
    external_citations = 0
    
    # Create a set of ISSNs that are both in the field and in the publisher set
    field_publisher_issns = issn_set & field_issns if field_issns else issn_set
    
    for citing_journal, cited_journals in issnEdges.items():
        if is_publisher_journal(citing_journal, field_publisher_issns):
            for cited_journal in cited_journals:
                if is_publisher_journal(cited_journal, field_publisher_issns):
                    internal_citations += 1
                elif field_issns is None or is_publisher_journal(cited_journal, field_issns):
                    external_citations += 1

    total_citations = internal_citations + external_citations
    internal_ratio = internal_citations / total_citations
    
    n = total_citations
    p = internal_ratio
    z = stats.norm.ppf((1 + confidence) / 2)
    denominator = 1 + z**2/n
    p_tilde = (p + z**2/(2*n)) / denominator
    stderr_tilde = z * np.sqrt(p*(1-p)/n + z**2/(4*n**2)) / denominator
    lower_bound = max(0, p_tilde - stderr_tilde)
    upper_bound = min(1, p_tilde + stderr_tilde)

    print(f"\n{name}")
    print(f"Internal citations: {internal_citations}")
    print(f"External citations: {external_citations}")
    print(f"Internal ratio: {internal_ratio:.4f}")
    print(f"95% Wilson score interval: ({lower_bound:.4f}, {upper_bound:.4f})")

    # Build the citation graph
    G = build_citation_graph(issnEdges)

    # Get top central journals
    top_journals = get_top_central_journals(G, issn_set)

    print(f"\nTop 50 most central journals for {name}:")
    for i, (journal, centrality) in enumerate(top_journals, 1):
        print(f"{i}. ISSN: {journal}, Centrality: {centrality:.4f}")

# %%
calculate_ratios(publisher_issns & publisher_issn_lookup, f"OJS (overall in Dimensions)")
calculate_ratios(publisher_issns & issnsID, f"Indonesian OJS (overall in Dimensions)")
# Out:
# OJS (overall in Dimensions)
# Internal citations: 8056513
# External citations: 19424042
# Internal ratio: 0.2932
# 95% Wilson score interval: (0.2930, 0.2933)
#
# Top 50 most central journals for OJS (overall in Dimensions):
# 1. ISSN: 0036-8075
# 1095-9203, Centrality: 0.5481
# 2. ISSN: 0028-0836
# 1476-4687, Centrality: 0.5271
# 3. ISSN: 1412-4262
# 2620-7389, Centrality: 0.1878
# 4. ISSN: 1857-9655
# 1857-5773, Centrality: 0.1744
# 5. ISSN: 1807-5932
# 1980-5322, Centrality: 0.1621
# 6. ISSN: 1937-8688, Centrality: 0.1620
# 7. ISSN: 1682-024X
# 1681-715X, Centrality: 0.1533
# 8. ISSN: 1680-6905
# 1729-0503, Centrality: 0.1498
# 9. ISSN: 0034-8910
# 1518-8787, Centrality: 0.1364
# 10. ISSN: 1424-7860
# 1424-3997, Centrality: 0.1312
# 11. ISSN: 1745-3674
# 1745-3682, Centrality: 0.1252
# 48. ISSN: 2614-4727
# 2614-4735, Centrality: 0.0196
# 49. ISSN: 2622-3740, Centrality: 0.0196
# 50. ISSN: 2086-4639
# 2460-5824, Centrality: 0.0193

# %% [markdown]
# ^ The most central publications in the non-Indonesian OJS graph are Science (0036-8075) and Nature (0028-0836), followed by Jurnal Agriculture.<br>
# In the Indonesian OJS citation graph, the most central are Jurnal Agriculture (1412-4262, 2620-7389), Personnel Review, & Ekonomika.

# %% [markdown]
# ## Describe subgraphs for specific medical publications

# %%
medIssns = {
    "Ethiopian Journal of Health Sciences": "1029-1857\n2413-7170",
    "Sultan Qaboos University Medical Journal": "2075-051X\n2075-0528",
    "Upsala Journal of Medical Sciences": "0300-9734\n2000-1967",
    "International Journal of Health Sciences": "1658-3639\n1658-7774",
    "Acta Dermato-Venereologica": "0001-5555\n1651-2057",
    "Revista do Instituto de Medicina Tropical de São Paulo": "0036-4665\n1678-9946",
    "EXCLI Journal: Experimental and Clinical Sciences": "1611-2156",
    "The Southern African Journal of Critical Care": "1562-8264\n2078-676X",
    "Acta Odontologica Scandinavica": "0001-6357\n1502-3850",
    "Acta Biomedica Atenei Parmensis": "0392-4203\n2531-6745",
    "Iranian Red Crescent Medical Journal": "2074-1804\n2074-1812",
    "Acta Orthopaedica": "1745-3674\n1745-3682",
    "African Health Sciences": "1680-6905\n1729-0503",
    "Pakistan Journal of Medical Sciences": "1682-024X\n1681-715X",
    "Open Access Macedonian Journal of Medical Sciences": "1857-9655\n1857-5773",
    "Scandinavian Journal of Urology": "2168-1805\n2168-1813",
    "Biomedica": "0120-4157\n2590-7379",
    "Journal of Evolution of Dental and Medical Sciences": "2278-4748\n2278-4802",
    "Journal of Rehabilitation Medicine": "1650-1977\n1651-2081",
    "Biomolecules and Biomedicine": "2831-0896\n2831-090X"
}

# %%
otherIssns = {
    "Journal of Statistical Software": "1548-7660",
    "Jurnal Agriculture": "1412-4262\n2620-7389"
}

# %%
def analyze_journal_network(name, issn, issn_edges, publisher_issns):
    G = nx.MultiGraph()  # Use a MultiGraph to allow multiple edges

    # Add the central node
    G.add_node(issn)
    
    # Add direct connections (one-hop neighbors)
    if issn in issn_edges:
        for connected_issn in issn_edges[issn]:
            if connected_issn is not None:
                G.add_edge(issn, connected_issn)
    
    # Add reverse connections
    for connecting_issn, connected_issns in issn_edges.items():
        if connecting_issn is not None and issn in connected_issns:
            for _ in range(connected_issns.count(issn)):
                G.add_edge(connecting_issn, issn)

    if issn not in G:
        print(f"ISSN {issn} not found in the network.")
        return None

    # Calculate metrics
    degree = sum(dict(G.degree()).values())
    
    total_nodes = G.number_of_nodes()
    total_edges = G.number_of_edges()
    
    # Calculate internal and external connections
    internal_connections = sum(1 for u, v in G.edges(issn) if v in publisher_issns)
    external_connections = sum(1 for u, v in G.edges(issn) if v not in publisher_issns)
    
    total_connections = internal_connections + external_connections
    internal_ratio = internal_connections / total_connections if total_connections > 0 else 0
    external_ratio = external_connections / total_connections if total_connections > 0 else 0
    
    self_connections = G.number_of_edges(issn, issn)
    within_pub_ratio = self_connections / degree if degree > 0 else 0
    
    # Count connections for each neighbor
    neighbors = {n: G.number_of_edges(issn, n) for n in G.neighbors(issn)}
    
    top_connected = sorted(neighbors.items(), key=lambda x: x[1], reverse=True)[:10]
    
    density = nx.density(G)
    
    print(f"Analysis for Journal: {name}")
    print(f"ISSN: {issn}")
    print(f"Total nodes in network: {total_nodes}")
    print(f"Total edges in network: {total_edges}")
    print(f"Degree (total connections): {degree}")
    print(f"OJS-Internal connections: {internal_connections}")
    print(f"OJS-External connections: {external_connections}")
    print(f"OJS-Internal connection ratio: {internal_ratio:.2f}")
    print(f"OJS-External connection ratio: {external_ratio:.2f}")
    print(f"Within-publication connection ratio: {within_pub_ratio:.2f}")
    print(f"Network density: {density:.4f}")
    
    print("\nTop 10 connected journals:")
    for journal, count in top_connected:
        print(f"  ISSN: {journal}, Connections: {count}")

    print("\n___________________________\n")
    
    return G

# %%
for name, issn in medIssns.items():
    analyze_journal_network(name, issn, issnEdges, publisher_issn_lookup)
# Out:
# Analysis for Journal: Ethiopian Journal of Health Sciences
# ISSN: 1029-1857
# 2413-7170
# Total nodes in network: 6041
# Total edges in network: 50059
# Degree (total connections): 100118
# OJS-Internal connections: 1837
# OJS-External connections: 48222
# OJS-Internal connection ratio: 0.04
# OJS-External connection ratio: 0.96
# Within-publication connection ratio: 0.02
# Network density: 0.0027
#
# Top 10 connected journals:
#   ISSN: 1029-1857
# 2413-7170, Connections: 1772
#   ISSN: 1932-6203, Connections: 1678
#   ISSN: 1471-2458, Connections: 704
#   ISSN: 1937-8688, Connections: 656
#   ISSN: 1471-2393, Connections: 625
#   ISSN: 0140-6736
# 1474-547X, Connections: 579
#   ISSN: 1021-6790
# 2309-7388, Connections: 560
#   ISSN: 1756-0500, Connections: 470
#   ISSN: 0014-1755
# 2415-2420, Connections: 469
#   ISSN: 1680-6905
# 1729-0503, Connections: 355
#
# ___________________________
#
# Analysis for Journal: Sultan Qaboos University Medical Journal
# ISSN: 2075-051X
# 2075-0528
# Total nodes in network: 6036
# Total edges in network: 42330
# Degree (total connections): 84660
# OJS-Internal connections: 671
# OJS-External connections: 41659
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.03
# Network density: 0.0023
#
# Top 10 connected journals:
#   ISSN: 2075-051X
# 2075-0528, Connections: 2660
#   ISSN: 0028-4793
# 1533-4406, Connections: 445
#   ISSN: 0140-6736
# 1474-547X, Connections: 382
#   ISSN: 1932-6203, Connections: 335
#   ISSN: 0028-0836
# 1476-4687, Connections: 255
#   ISSN: 1999-768X
# 2070-5204, Connections: 252
#   ISSN: 0959-8138
# 1756-1833, Connections: 237
#   ISSN: 0036-8075
# 1095-9203, Connections: 227
#   ISSN: 1661-7827
# 1660-4601, Connections: 211
#   ISSN: 0098-7484
# 1538-3598, Connections: 210
#
# ___________________________
#
# Analysis for Journal: Upsala Journal of Medical Sciences
# ISSN: 0300-9734
# 2000-1967
# Total nodes in network: 5877
# Total edges in network: 65440
# Degree (total connections): 130880
# OJS-Internal connections: 157
# OJS-External connections: 65283
# OJS-Internal connection ratio: 0.00
# OJS-External connection ratio: 1.00
# Within-publication connection ratio: 0.03
# Network density: 0.0038
#
# Top 10 connected journals:
#   ISSN: 0300-9734
# 2000-1967, Connections: 3930
#   ISSN: 0028-0836
# 1476-4687, Connections: 1287
#   ISSN: 0036-8075
# 1095-9203, Connections: 874
#   ISSN: 0012-1797
# 1939-327X, Connections: 860
#   ISSN: 0021-9258
# 1083-351X, Connections: 616
#   ISSN: 0027-8424
# 1091-6490, Connections: 599
#   ISSN: 0268-1161
# 1460-2350, Connections: 572
#   ISSN: 0012-186X
# 1432-0428, Connections: 543
#   ISSN: 1932-6203, Connections: 540
#   ISSN: 0140-6736
# 1474-547X, Connections: 532
#
# ___________________________
#
# Analysis for Journal: International Journal of Health Sciences
# ISSN: 1658-3639
# 1658-7774
# Total nodes in network: 6249
# Total edges in network: 36584
# Degree (total connections): 73168
# OJS-Internal connections: 837
# OJS-External connections: 35747
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.02
# Network density: 0.0019
#
# Top 10 connected journals:
#   ISSN: 1658-3639
# 1658-7774, Connections: 1304
#   ISSN: 1932-6203, Connections: 460
#   ISSN: 2168-8184, Connections: 282
#   ISSN: 0379-5284
# 1658-3175, Connections: 255
#   ISSN: 0140-6736
# 1474-547X, Connections: 230
#   ISSN: 1661-7827
# 1660-4601, Connections: 210
#   ISSN: 0028-4793
# 1533-4406, Connections: 181
#   ISSN: 0036-8075
# 1095-9203, Connections: 165
#   ISSN: 1471-2458, Connections: 159
#   ISSN: 1661-6596
# 1422-0067, Connections: 147
#
# ___________________________
#
# Analysis for Journal: Acta Dermato-Venereologica
# ISSN: 0001-5555
# 1651-2057
# Total nodes in network: 6182
# Total edges in network: 96369
# Degree (total connections): 192738
# OJS-Internal connections: 541
# OJS-External connections: 95828
# OJS-Internal connection ratio: 0.01
# OJS-External connection ratio: 0.99
# Within-publication connection ratio: 0.03
# Network density: 0.0050
#
# Top 10 connected journals:
#   ISSN: 0001-5555
# 1651-2057, Connections: 5356
#   ISSN: 0007-0963
# 1365-2133, Connections: 4792
#   ISSN: 0190-9622
# 1097-6787, Connections: 3692
#   ISSN: 0926-9959
# 1468-3083, Connections: 3643
#   ISSN: 0022-202X
# 1523-1747, Connections: 2152
#   ISSN: 0105-1873
# 1600-0536, Connections: 1507
#   ISSN: 0011-9059
# 1365-4632, Connections: 1506
#   ISSN: 2168-6068
# 2168-6084, Connections: 1388
#   ISSN: 0385-2407
# 1346-8138, Connections: 1037
#   ISSN: 0001-7310
# 2173-5778, Connections: 891
#
# ___________________________
#
# Analysis for Journal: Revista do Instituto de Medicina Tropical de São Paulo
# ISSN: 0036-4665
# 1678-9946
# Total nodes in network: 5992
# Total edges in network: 156762
# Degree (total connections): 313524
# OJS-Internal connections: 1108
# OJS-External connections: 155654
# OJS-Internal connection ratio: 0.01
# OJS-External connection ratio: 0.99
# Within-publication connection ratio: 0.06
# Network density: 0.0087
#
# Top 10 connected journals:
#   ISSN: 0036-4665
# 1678-9946, Connections: 17670
#   ISSN: 0037-8682
# 1678-9849, Connections: 5764
#   ISSN: 0074-0276
# 1678-8060, Connections: 4519
#   ISSN: 0002-9637
# 1476-1645, Connections: 3808
#   ISSN: 0034-8910
# 1518-8787, Connections: 3500
#   ISSN: 0095-1137
# 1098-660X, Connections: 2725
#   ISSN: 0035-9203
# 1878-3503, Connections: 2501
#   ISSN: 1935-2727
# 1935-2735, Connections: 2023
#   ISSN: 0001-706X
# 1873-6254, Connections: 1934
#   ISSN: 1932-6203, Connections: 1574
#
# ___________________________
#
# Analysis for Journal: EXCLI Journal: Experimental and Clinical Sciences
# ISSN: 1611-2156
# Total nodes in network: 6833
# Total edges in network: 80049
# Degree (total connections): 160098
# OJS-Internal connections: 3004
# OJS-External connections: 77045
# OJS-Internal connection ratio: 0.04
# OJS-External connection ratio: 0.96
# Within-publication connection ratio: 0.02
# Network density: 0.0034
#
# Top 10 connected journals:
#   ISSN: 1611-2156, Connections: 2558
#   ISSN: 0340-5761
# 1432-0738, Connections: 1502
#   ISSN: 1932-6203, Connections: 941
#   ISSN: 0028-0836
# 1476-4687, Connections: 937
#   ISSN: 1661-6596
# 1422-0067, Connections: 735
#   ISSN: 0036-8075
# 1095-9203, Connections: 666
#   ISSN: 1420-3049, Connections: 578
#   ISSN: 0021-9258
# 1083-351X, Connections: 567
#   ISSN: 0027-8424
# 1091-6490, Connections: 548
#   ISSN: 0378-8741
# 1872-7573, Connections: 547
#
# ___________________________
#
# Analysis for Journal: The Southern African Journal of Critical Care
# ISSN: 1562-8264
# 2078-676X
# Total nodes in network: 7395
# Total edges in network: 76776
# Degree (total connections): 153552
# OJS-Internal connections: 1852
# OJS-External connections: 74924
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.03
# Network density: 0.0028
#
# Top 10 connected journals:
#   ISSN: 1562-8264
# 2078-676X, Connections: 3896
#   ISSN: 2078-6190
# 2078-6204, Connections: 2338
#   ISSN: 1932-6203, Connections: 1769
#   ISSN: 2071-2928
# 2071-2936, Connections: 1438
#   ISSN: 1937-8688, Connections: 840
#   ISSN: 0140-6736
# 1474-547X, Connections: 736
#   ISSN: 1471-2458, Connections: 645
#   ISSN: 1608-9693
# 2078-6751, Connections: 630
#   ISSN: 1680-6905
# 1729-0503, Connections: 586
#   ISSN: 1661-7827
# 1660-4601, Connections: 557
#
# ___________________________
#
# Analysis for Journal: Acta Odontologica Scandinavica
# ISSN: 0001-6357
# 1502-3850
# Total nodes in network: 6995
# Total edges in network: 285459
# Degree (total connections): 570918
# OJS-Internal connections: 927
# OJS-External connections: 284532
# OJS-Internal connection ratio: 0.00
# OJS-External connection ratio: 1.00
# Within-publication connection ratio: 0.06
# Network density: 0.0117
#
# Top 10 connected journals:
#   ISSN: 0001-6357
# 1502-3850, Connections: 34946
#   ISSN: 1045-4411
# 1544-1113, Connections: 9518
#   ISSN: 0022-3913
# 1097-6841, Connections: 7704
#   ISSN: 0909-8836
# 1600-0722, Connections: 7050
#   ISSN: 0301-5661
# 1600-0528, Connections: 6821
#   ISSN: 0305-182X
# 1365-2842, Connections: 6329
#   ISSN: 0003-9969
# 1879-1506, Connections: 5791
#   ISSN: 2212-4403
# 2212-4411, Connections: 4625
#   ISSN: 0008-6568
# 1421-976X, Connections: 4606
#   ISSN: 0002-8177
# 1943-4723, Connections: 4514
#
# ___________________________
#
# Analysis for Journal: Acta Biomedica Atenei Parmensis
# ISSN: 0392-4203
# 2531-6745
# Total nodes in network: 7331
# Total edges in network: 85393
# Degree (total connections): 170786
# OJS-Internal connections: 890
# OJS-External connections: 84503
# OJS-Internal connection ratio: 0.01
# OJS-External connection ratio: 0.99
# Within-publication connection ratio: 0.04
# Network density: 0.0032
#
# Top 10 connected journals:
#   ISSN: 0392-4203
# 2531-6745, Connections: 6836
#   ISSN: 1661-7827
# 1660-4601, Connections: 812
#   ISSN: 0026-4962
# 1826-6983, Connections: 780
#   ISSN: 0140-6736
# 1474-547X, Connections: 693
#   ISSN: 0028-4793
# 1533-4406, Connections: 684
#   ISSN: 0021-9355
# 1535-1386, Connections: 665
#   ISSN: 0009-921X
# 1528-1132, Connections: 654
#   ISSN: 1932-6203, Connections: 569
#   ISSN: 1745-3674
# 1745-3682, Connections: 478
#   ISSN: 1121-2233
# 2421-4248, Connections: 462
#
# ___________________________
#
# Analysis for Journal: Iranian Red Crescent Medical Journal
# ISSN: 2074-1804
# 2074-1812
# Total nodes in network: 7877
# Total edges in network: 68127
# Degree (total connections): 136254
# OJS-Internal connections: 1048
# OJS-External connections: 67079
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.01
# Network density: 0.0022
#
# Top 10 connected journals:
#   ISSN: 2074-1804
# 2074-1812, Connections: 1938
#   ISSN: 1932-6203, Connections: 548
#   ISSN: 2008-3645
# 2008-4161, Connections: 465
#   ISSN: 0140-6736
# 1474-547X, Connections: 408
#   ISSN: 1471-2458, Connections: 334
#   ISSN: 2008-5842, Connections: 307
#   ISSN: 0028-4793
# 1533-4406, Connections: 272
#   ISSN: 0304-4556
# 2251-6093, Connections: 271
#   ISSN: 0378-8741
# 1872-7573, Connections: 251
#   ISSN: 0098-7484
# 1538-3598, Connections: 243
#
# ___________________________
#
# Analysis for Journal: Acta Orthopaedica
# ISSN: 1745-3674
# 1745-3682
# Total nodes in network: 8486
# Total edges in network: 653179
# Degree (total connections): 1306358
# OJS-Internal connections: 1339
# OJS-External connections: 651840
# OJS-Internal connection ratio: 0.00
# OJS-External connection ratio: 1.00
# Within-publication connection ratio: 0.09
# Network density: 0.0181
#
# Top 10 connected journals:
#   ISSN: 1745-3674
# 1745-3682, Connections: 112548
#   ISSN: 0021-9355
# 1535-1386, Connections: 34251
#   ISSN: 0009-921X
# 1528-1132, Connections: 31488
#   ISSN: 2049-4394
# 2049-4408, Connections: 24820
#   ISSN: 0883-5403
# 1532-8406, Connections: 19014
#   ISSN: 0936-8051
# 1434-3916, Connections: 9276
#   ISSN: 0020-1383
# 1879-0267, Connections: 7987
#   ISSN: 0736-0266
# 1554-527X, Connections: 7413
#   ISSN: 0341-2695
# 1432-5195, Connections: 7343
#   ISSN: 0362-2436
# 1528-1159, Connections: 6022
#
# ___________________________
#
# Analysis for Journal: African Health Sciences
# ISSN: 1680-6905
# 1729-0503
# Total nodes in network: 9607
# Total edges in network: 156014
# Degree (total connections): 312028
# OJS-Internal connections: 5101
# OJS-External connections: 150913
# OJS-Internal connection ratio: 0.03
# OJS-External connection ratio: 0.97
# Within-publication connection ratio: 0.05
# Network density: 0.0034
#
# Top 10 connected journals:
#   ISSN: 1680-6905
# 1729-0503, Connections: 14640
#   ISSN: 1932-6203, Connections: 3241
#   ISSN: 0140-6736
# 1474-547X, Connections: 1866
#   ISSN: 1937-8688, Connections: 1738
#   ISSN: 1471-2458, Connections: 1559
#   ISSN: 0012-835X, Connections: 1015
#   ISSN: 0028-4793
# 1533-4406, Connections: 863
#   ISSN: 1471-2334, Connections: 775
#   ISSN: 0269-9370
# 1473-5571, Connections: 757
#   ISSN: 1058-4838
# 1537-6591, Connections: 692
#
# ___________________________
#
# Analysis for Journal: Pakistan Journal of Medical Sciences
# ISSN: 1682-024X
# 1681-715X
# Total nodes in network: 9831
# Total edges in network: 112346
# Degree (total connections): 224692
# OJS-Internal connections: 4018
# OJS-External connections: 108328
# OJS-Internal connection ratio: 0.04
# OJS-External connection ratio: 0.96
# Within-publication connection ratio: 0.04
# Network density: 0.0023
#
# Top 10 connected journals:
#   ISSN: 1682-024X
# 1681-715X, Connections: 8756
#   ISSN: 0030-9982, Connections: 2315
#   ISSN: 1932-6203, Connections: 1268
#   ISSN: 2168-8184, Connections: 839
#   ISSN: 1025-9589
# 1819-2718, Connections: 675
#   ISSN: 0028-4793
# 1533-4406, Connections: 659
#   ISSN: 1661-7827
# 1660-4601, Connections: 654
#   ISSN: 0140-6736
# 1474-547X, Connections: 646
#   ISSN: 1022-386X
# 1681-7168, Connections: 600
#   ISSN: 1066-9442
# 1935-5548, Connections: 526
#
# ___________________________
#
# Analysis for Journal: Open Access Macedonian Journal of Medical Sciences
# ISSN: 1857-9655
# 1857-5773
# Total nodes in network: 12013
# Total edges in network: 119905
# Degree (total connections): 239810
# OJS-Internal connections: 2891
# OJS-External connections: 117014
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.02
# Network density: 0.0017
#
# Top 10 connected journals:
#   ISSN: 1857-9655
# 1857-5773, Connections: 5000
#   ISSN: 1932-6203, Connections: 1577
#   ISSN: 0140-6736
# 1474-547X, Connections: 732
#   ISSN: 1661-7827
# 1660-4601, Connections: 596
#   ISSN: 0028-4793
# 1533-4406, Connections: 581
#   ISSN: 1471-2458, Connections: 481
#   ISSN: 0028-0836
# 1476-4687, Connections: 434
#   ISSN: 2045-2322, Connections: 410
#   ISSN: 2072-6643, Connections: 389
#   ISSN: 0098-7484
# 1538-3598, Connections: 378
#
# ___________________________
#
# Analysis for Journal: Scandinavian Journal of Urology
# ISSN: 2168-1805
# 2168-1813
# Total nodes in network: 5139
# Total edges in network: 139992
# Degree (total connections): 279984
# OJS-Internal connections: 284
# OJS-External connections: 139708
# OJS-Internal connection ratio: 0.00
# OJS-External connection ratio: 1.00
# Within-publication connection ratio: 0.06
# Network density: 0.0106
#
# Top 10 connected journals:
#   ISSN: 2168-1805
# 2168-1813, Connections: 16696
#   ISSN: 0021-0005
# 1527-3792, Connections: 14414
#   ISSN: 1464-4096
# 1464-410X, Connections: 6539
#   ISSN: 0090-4295
# 1527-9995, Connections: 4627
#   ISSN: 0302-2838
# 1873-7560, Connections: 4107
#   ISSN: 0733-2467
# 1520-6777, Connections: 1454
#   ISSN: 0008-543X
# 1097-0142, Connections: 1453
#   ISSN: 0892-7790
# 1557-900X, Connections: 1202
#   ISSN: 0085-2538
# 1523-1755, Connections: 1181
#   ISSN: 0394-2511
# 1423-0399, Connections: 1177
#
# ___________________________
#
# Analysis for Journal: Biomedica
# ISSN: 0120-4157
# 2590-7379
# Total nodes in network: 5372
# Total edges in network: 59669
# Degree (total connections): 119338
# OJS-Internal connections: 741
# OJS-External connections: 58928
# OJS-Internal connection ratio: 0.01
# OJS-External connection ratio: 0.99
# Within-publication connection ratio: 0.04
# Network density: 0.0041
#
# Top 10 connected journals:
#   ISSN: 0120-4157
# 2590-7379, Connections: 4944
#   ISSN: 0002-9637
# 1476-1645, Connections: 1248
#   ISSN: 0074-0276
# 1678-8060, Connections: 943
#   ISSN: 1932-6203, Connections: 894
#   ISSN: 0123-9392
# 2422-3794, Connections: 755
#   ISSN: 0036-4665
# 1678-9946, Connections: 660
#   ISSN: 1935-2727
# 1935-2735, Connections: 647
#   ISSN: 0124-0064
# 1852-9429, Connections: 624
#   ISSN: 0095-1137
# 1098-660X, Connections: 570
#   ISSN: 0001-706X
# 1873-6254, Connections: 551
#
# ___________________________
#
# Analysis for Journal: Journal of Evolution of Dental and Medical Sciences
# ISSN: 2278-4748
# 2278-4802
# Total nodes in network: 6057
# Total edges in network: 61195
# Degree (total connections): 122390
# OJS-Internal connections: 1134
# OJS-External connections: 60061
# OJS-Internal connection ratio: 0.02
# OJS-External connection ratio: 0.98
# Within-publication connection ratio: 0.02
# Network density: 0.0033
#
# Top 10 connected journals:
#   ISSN: 2278-4748
# 2278-4802, Connections: 2168
#   ISSN: 0140-6736
# 1474-547X, Connections: 573
#   ISSN: 0003-2999
# 1526-7598, Connections: 569
#   ISSN: 1745-3674
# 1745-3682, Connections: 501
#   ISSN: 2320-6071
# 2320-6012, Connections: 480
#   ISSN: 0028-4793
# 1533-4406, Connections: 453
#   ISSN: 2320-1770
# 2320-1789, Connections: 452
#   ISSN: 0021-9355
# 1535-1386, Connections: 434
#   ISSN: 0002-9378
# 1097-6868, Connections: 433
#   ISSN: 0003-3022
# 1528-1175, Connections: 412
#
# ___________________________
#
# Analysis for Journal: Journal of Rehabilitation Medicine
# ISSN: 1650-1977
# 1651-2081
# Total nodes in network: 6126
# Total edges in network: 90876
# Degree (total connections): 181752
# OJS-Internal connections: 1127
# OJS-External connections: 89749
# OJS-Internal connection ratio: 0.01
# OJS-External connection ratio: 0.99
# Within-publication connection ratio: 0.02
# Network density: 0.0048
#
# Top 10 connected journals:
#   ISSN: 0963-8288
# 1464-5165, Connections: 3325
#   ISSN: 1650-1977
# 1651-2081, Connections: 2994
#   ISSN: 0003-9993
# 1532-821X, Connections: 2921
#   ISSN: 0269-2155
# 1477-0873, Connections: 1140
#   ISSN: 1932-6203, Connections: 1014
#   ISSN: 0031-9023
# 1538-6724, Connections: 1004
#   ISSN: 0894-9115
# 1537-7385, Connections: 913
#   ISSN: 1362-4393
# 1476-5624, Connections: 857
#   ISSN: 0362-2436
# 1528-1159, Connections: 775
#   ISSN: 1661-7827
# 1660-4601, Connections: 722
#
# ___________________________
#
# Analysis for Journal: Biomolecules and Biomedicine
# ISSN: 2831-0896
# 2831-090X
# Total nodes in network: 5519
# Total edges in network: 42699
# Degree (total connections): 85398
# OJS-Internal connections: 211
# OJS-External connections: 42488
# OJS-Internal connection ratio: 0.00
# OJS-External connection ratio: 1.00
# Within-publication connection ratio: 0.02
# Network density: 0.0028
#
# Top 10 connected journals:
#   ISSN: 2831-0896
# 2831-090X, Connections: 1508
#   ISSN: 0028-0836
# 1476-4687, Connections: 663
#   ISSN: 1932-6203, Connections: 416
#   ISSN: 1661-6596
# 1422-0067, Connections: 394
#   ISSN: 0036-8075
# 1095-9203, Connections: 379
#   ISSN: 0028-4793
# 1533-4406, Connections: 334
#   ISSN: 2045-2322, Connections: 270
#   ISSN: 0027-8424
# 1091-6490, Connections: 262
#   ISSN: 0140-6736
# 1474-547X, Connections: 224
#   ISSN: 0021-9258
# 1083-351X, Connections: 223
#
# ___________________________

# %%
def analyze_journal_network_directed(name, issn, issn_edges, publisher_issns):
    G = nx.MultiDiGraph()  # Use a MultiDiGraph for directed edges with multiple connections

    # Add the central node
    G.add_node(issn)
    
    # Add outgoing edges (citations made by the journal)
    if issn in issn_edges:
        for cited_issn in issn_edges[issn]:
            if cited_issn is not None:
                G.add_edge(issn, cited_issn)
    
    # Add incoming edges (citations received by the journal)
    for citing_issn, cited_issns in issn_edges.items():
        if citing_issn is not None:
            for cited_issn in cited_issns:
                if cited_issn == issn:
                    G.add_edge(citing_issn, issn)

    if issn not in G:
        print(f"ISSN {issn} not found in the network.")
        return None

    # Calculate metrics
    in_degree = G.in_degree(issn)
    out_degree = G.out_degree(issn)
    total_degree = in_degree + out_degree
    
    total_nodes = G.number_of_nodes()
    total_edges = G.number_of_edges()
    
    # Calculate internal and external connections
    internal_citations_made = sum(1 for _, v, _ in G.out_edges(issn, keys=True) if v in publisher_issns)
    external_citations_made = sum(1 for _, v, _ in G.out_edges(issn, keys=True) if v not in publisher_issns)
    internal_citations_received = sum(1 for u, _, _ in G.in_edges(issn, keys=True) if u in publisher_issns)
    external_citations_received = sum(1 for u, _, _ in G.in_edges(issn, keys=True) if u not in publisher_issns)
    
    total_citations_made = internal_citations_made + external_citations_made
    total_citations_received = internal_citations_received + external_citations_received
    
    internal_ratio_made = internal_citations_made / total_citations_made if total_citations_made > 0 else 0
    external_ratio_made = external_citations_made / total_citations_made if total_citations_made > 0 else 0
    internal_ratio_received = internal_citations_received / total_citations_received if total_citations_received > 0 else 0
    external_ratio_received = external_citations_received / total_citations_received if total_citations_received > 0 else 0
    
    self_citations = G.number_of_edges(issn, issn)
    self_citation_ratio = self_citations / total_degree if total_degree > 0 else 0
    
    # Count connections for each neighbor
    cited_journals = {n: G.number_of_edges(issn, n) for n in G.successors(issn)}
    citing_journals = {n: G.number_of_edges(n, issn) for n in G.predecessors(issn)}
    
    top_cited = sorted(cited_journals.items(), key=lambda x: x[1], reverse=True)[:5]
    top_citing = sorted(citing_journals.items(), key=lambda x: x[1], reverse=True)[:5]
    
    density = nx.density(G)
    
    print(f"Analysis for Journal: {name}")
    print(f"ISSN: {issn}")
    print(f"Total nodes in network: {total_nodes}")
    print(f"Total edges in network: {total_edges}")
    print(f"In-degree (citations received): {in_degree}")
    print(f"Out-degree (citations made): {out_degree}")
    print(f"Total degree: {total_degree}")
    print(f"OJS-Internal citations made: {internal_citations_made}")
    print(f"OJS-External citations made: {external_citations_made}")
    print(f"OJS-Internal citations received: {internal_citations_received}")
    print(f"OJS-External citations received: {external_citations_received}")
    print(f"OJS-Internal citation ratio (made): {internal_ratio_made:.2f}")
    print(f"OJS-External citation ratio (made): {external_ratio_made:.2f}")
    print(f"OJS-Internal citation ratio (received): {internal_ratio_received:.2f}")
    print(f"OJS-External citation ratio (received): {external_ratio_received:.2f}")
    print(f"Self-citation ratio: {self_citation_ratio:.2f}")
    print(f"Network density: {density:.4f}")
    
    print("\nTop 5 cited journals:")
    for journal, count in top_cited:
        print(f"  ISSN: {journal}, Citations: {count}")
    
    print("\nTop 5 citing journals:")
    for journal, count in top_citing:
        print(f"  ISSN: {journal}, Citations: {count}")

    print("\n___________________________\n")
    
    return G

# %%
for name, issn in medIssns.items():
    analyze_journal_network_directed(name, issn, issnEdges, publisher_issn_lookup)
# Out:
# Analysis for Journal: Ethiopian Journal of Health Sciences
# ISSN: 1029-1857
# 2413-7170
# Total nodes in network: 6041
# Total edges in network: 50059
# In-degree (citations received): 20611
# Out-degree (citations made): 31220
# Total degree: 51831
# OJS-Internal citations made: 1095
# OJS-External citations made: 30125
# OJS-Internal citations received: 742
# OJS-External citations received: 19869
# OJS-Internal citation ratio (made): 0.04
# OJS-External citation ratio (made): 0.96
# OJS-Internal citation ratio (received): 0.04
# OJS-External citation ratio (received): 0.96
# Self-citation ratio: 0.03
# Network density: 0.0014
#
# Top 5 cited journals:
#   ISSN: 1029-1857
# 2413-7170, Citations: 1772
#   ISSN: 0140-6736
# 1474-547X, Citations: 572
#   ISSN: 1932-6203, Citations: 570
#   ISSN: 1021-6790
# 2309-7388, Citations: 560
#   ISSN: 0014-1755
# 2415-2420, Citations: 469
#
# Top 5 citing journals:
#   ISSN: 1029-1857
# 2413-7170, Citations: 1772
#   ISSN: 1932-6203, Citations: 1108
#   ISSN: 1471-2393, Citations: 368
#   ISSN: 1937-8688, Citations: 337
#   ISSN: 1756-0500, Citations: 318
#
# ___________________________
#
# Analysis for Journal: Sultan Qaboos University Medical Journal
# ISSN: 2075-051X
# 2075-0528
# Total nodes in network: 6036
# Total edges in network: 42330
# In-degree (citations received): 15472
# Out-degree (citations made): 29518
# Total degree: 44990
# OJS-Internal citations made: 333
# OJS-External citations made: 29185
# OJS-Internal citations received: 338
# OJS-External citations received: 15134
# OJS-Internal citation ratio (made): 0.01
# OJS-External citation ratio (made): 0.99
# OJS-Internal citation ratio (received): 0.02
# OJS-External citation ratio (received): 0.98
# Self-citation ratio: 0.06
# Network density: 0.0012
#
# Top 5 cited journals:
#   ISSN: 2075-051X
# 2075-0528, Citations: 2660
#   ISSN: 0028-4793
# 1533-4406, Citations: 442
#   ISSN: 0140-6736
# 1474-547X, Citations: 382
#   ISSN: 0028-0836
# 1476-4687, Citations: 252
#   ISSN: 0959-8138
# 1756-1833, Citations: 235
#
# Top 5 citing journals:
#   ISSN: 2075-051X
# 2075-0528, Citations: 2660
#   ISSN: 1932-6203, Citations: 162
#   ISSN: 1661-7827
# 1660-4601, Citations: 159
#   ISSN: 2168-8184, Citations: 151
#   ISSN: 1999-768X
# 2070-5204, Citations: 137
#
# ___________________________
#
# Analysis for Journal: Upsala Journal of Medical Sciences
# ISSN: 0300-9734
# 2000-1967
# Total nodes in network: 5877
# Total edges in network: 65440
# In-degree (citations received): 27526
# Out-degree (citations made): 41844
# Total degree: 69370
# OJS-Internal citations made: 31
# OJS-External citations made: 41813
# OJS-Internal citations received: 126
# OJS-External citations received: 27400
# OJS-Internal citation ratio (made): 0.00
# OJS-External citation ratio (made): 1.00
# OJS-Internal citation ratio (received): 0.00
# OJS-External citation ratio (received): 1.00
# Self-citation ratio: 0.06
# Network density: 0.0019
#
# Top 5 cited journals:
#   ISSN: 0300-9734
# 2000-1967, Citations: 3930
#   ISSN: 0028-0836
# 1476-4687, Citations: 1143
#   ISSN: 0036-8075
# 1095-9203, Citations: 858
#   ISSN: 0012-1797
# 1939-327X, Citations: 769
#   ISSN: 0027-8424
# 1091-6490, Citations: 559
#
# Top 5 citing journals:
#   ISSN: 0300-9734
# 2000-1967, Citations: 3930
#   ISSN: 1932-6203, Citations: 333
#   ISSN: 2045-2322, Citations: 203
#   ISSN: 1661-6596
# 1422-0067, Citations: 199
#   ISSN: 1745-3674
# 1745-3682, Citations: 196
#
# ___________________________
#
# Analysis for Journal: International Journal of Health Sciences
# ISSN: 1658-3639
# 1658-7774
# Total nodes in network: 6249
# Total edges in network: 36584
# In-degree (citations received): 14157
# Out-degree (citations made): 23731
# Total degree: 37888
# OJS-Internal citations made: 414
# OJS-External citations made: 23317
# OJS-Internal citations received: 423
# OJS-External citations received: 13734
# OJS-Internal citation ratio (made): 0.02
# OJS-External citation ratio (made): 0.98
# OJS-Internal citation ratio (received): 0.03
# OJS-External citation ratio (received): 0.97
# Self-citation ratio: 0
# 2531-6745
# Total nodes in network: 7331
# Total edges in network: 85393
# In-degree (citations received): 27389
# Out-degree (citations made): 64840
# Total degree: 92229
# OJS-Internal citations made: 481
# OJS-External citations made: 64359
# OJS-Internal citations received: 409
# OJS-External citations received: 26980
# OJS-Internal citation ratio (made): 0.01
# OJS-External citation ratio (made): 0.99
# OJS-Internal citation ratio (received): 0.01
# OJS-External citation ratio (received): 0.99
# Self-citation ratio: 0.07
# Network density: 0.0016
#
# Top 5 cited journals:
#   ISSN: 0392-4203
# 2531-6745, Citations: 6836
#   ISSN: 0026-4962
# 1826-6983, Citations: 721
#   ISSN: 0140-6736
# 1474-547X, Citations: 691
#   ISSN: 0028-4793
# 1533-4406, Citations: 682
#   ISSN: 0021-9355
# 1535-1386, Citations: 644
#
# Top 5 citing journals:
#   ISSN: 0392-4203
# 2531-6745, Citations: 6836
#   ISSN: 1661-7827
# 1660-4601, Citations: 580
#   ISSN: 2168-8184, Citations: 273
#   ISSN: 2077-0383, Citations: 270
#   ISSN: 1121-2233
# 2421-4248, Citations: 213
#
# ___________________________
#
# Analysis for Journal: Iranian Red Crescent Medical Journal
# ISSN: 2074-1804
# 2074-1812
# Total nodes in network: 7877
# Total edges in network: 68127
# In-degree (citations received): 24998
# Out-degree (citations made): 45067
# Total degree: 70065
# OJS-Internal citations made: 347
# OJS-External citations made: 44720
# OJS-Internal citations received: 701
# OJS-External citations received: 24297
# OJS-Internal citation ratio (made): 0.01
# OJS-External citation ratio (made): 0.99
# OJS-Internal citation ratio (received): 0.03
# OJS-External citation ratio (received): 0.97
# Self-citation ratio: 0.03
# Network density: 0.0011
#
# Top 5 cited journals:
#   ISSN: 2074-1804
# 2074-1812, Citations: 1938
#   ISSN: 0140-6736
# 1474-547X, Citations: 400
#   ISSN: 1932-6203, Citations: 291
#   ISSN: 0028-4793
# 1533-4406, Citations: 272
#   ISSN: 0098-7484
# 1538-3598, Citations: 238
#
# Top 5 citing journals:
#   ISSN: 2074-1804
# 2074-1812, Citations: 1938
#   ISSN: 2008-3645
# 2008-4161, Citations: 266
#   ISSN: 2008-5842, Citations: 260
#   ISSN: 1932-6203, Citations: 257
#   ISSN: 1661-7827
# 1660-4601, Citations: 177
#
# ___________________________
#
# Analysis for Journal: Acta Orthopaedica
# ISSN: 1745-3674
# 1745-3682
# Total nodes in network: 8486
# Total edges in network: 653179
# In-degree (citations received): 459307
# Out-degree (citations made): 306420
# Total degree: 765727
# OJS-Internal citations made: 65
# OJS-External citations made: 306355
# OJS-Internal citations received: 1274
# OJS-External citations received: 458033
# OJS-Internal citation ratio (made): 0.00
# OJS-External citation ratio (made): 1.00
# OJS-Internal citation ratio (received): 0.00
# OJS-External citation ratio (received): 1.00
# Self-citation ratio: 0.15
# Network density: 0.0091
#
# Top 5 cited journals:
#   ISSN: 1745-3674
# 1745-3682, Citations: 112548
#   ISSN: 0021-9355
# 1535-1386, Citations: 25671
#   ISSN: 0009-921X
# 1528-1132, Citations: 20267
#   ISSN: 2049-4394
# 2049-4408, Citations: 18007
#   ISSN: 0883-5403
# 1532-8406, Citations: 7094
#
# Top 5 citing journals:
#   ISSN: 1745-3674
# 1745-3682, Citations: 112548
#   ISSN: 0883-5403
# 1532-8406, Citations: 11920
#   ISSN: 0009-921X
# 1528-1132, Citations: 11221
#   ISSN: 0021-9355
# 1535-1386, Citations: 8580
#   ISSN: 0936-8051
# 1434-3916, Citations: 6915
#
# ___________________________
#
# Analysis for Journal: African Health Sciences
# ISSN: 1680-6905
# 1729-0503
# Total nodes in network: 9607
# Total edges in network: 156014
# In-degree (citations received): 60023
# Out-degree (citations made): 110631
# Total degree: 170654
# OJS-Internal citations made: 3131
# OJS-External citations made: 107500
# OJS-Internal citations received: 1970
# OJS-External citations received: 58053
# OJS-Internal citation ratio (made): 0.03
# OJS-External citation ratio (made): 0.97
# OJS-Internal citation ratio (received): 0.03
# OJS-External citation ratio (received): 0.97
# Self-citation ratio: 0.09
# Network density: 0.0017
#
# Top 5 cited journals:
#   ISSN: 1680-6905
# 1729-0503, Citations: 14640
#   ISSN: 0140-6736
# 1474-547X, Citations: 1819
#   ISSN: 1932-6203, Citations: 1715
#   ISSN: 0012-835X, Citations: 1006
#   ISSN: 1471-2458, Citations: 944
#
# Top 5 citing journals:
#   ISSN: 1680-6905
# 1729-0503, Citations: 14640
#   ISSN: 1932-6203, Citations: 1526
#   ISSN: 1937-8688, Citations: 1027
#   ISSN: 1471-2458, Citations: 615
#   ISSN: 1661-7827
# 1660-4601, Citations: 445
#
# ___________________________
#
# Analysis for Journal: Pakistan Journal of Medical Sciences
# ISSN: 1682-024X
# 1681-715X
# Total nodes in network: 9831
# Total edges in network: 112346
# In-degree (citations received): 41903
# Out-degree (citations made): 79199
# Total degree: 121102
# OJS-Internal citations made: 3033
# OJS-External citations made: 76166
# OJS-Internal citations received: 985
# OJS-External citations received: 40918
# OJS-Internal citation ratio (made): 0.04
# OJS-External citation ratio (made): 0.96
# OJS-Internal citation ratio (received): 0.02
# OJS-External citation ratio (received): 0.98
# Self-citation ratio: 0.07
# Network density: 0.0012
#
# Top 5 cited journals:
#   ISSN: 1682-024X
# 1681-715X, Citations: 8756
#   ISSN: 0030-9982, Citations: 2315
#   ISSN: 1932-6203, Citations: 794
#   ISSN: 1025-9589
# 1819-2718, Citations: 675
#   ISSN: 0028-4793
# 1533-4406, Citations: 659
#
# Top 5 citing journals:
#   ISSN: 1682-024X
# 1681-715X, Citations: 8756
#   ISSN: 2168-8184, Citations: 688
#   ISSN: 1661-7827
# 1660-4601, Citations: 532
#   ISSN: 1932-6203, Citations: 474
#   ISSN: 1472-6920, Citations: 205
#
# ___________________________
#
# Analysis for Journal: Open Access Macedonian Journal of Medical Sciences
# ISSN: 1857-9655
# 1857-5773
# Total nodes in network: 12013
# Total edges in network: 119905
# In-degree (citations received): 23670
# Out-degree (citations made): 101235
# Total degree: 124905
# OJS-Internal citations made: 2150
# OJS-External citations made: 99085
# OJS-Internal citations received: 741
# OJS-External citations received: 22929
# OJS-Internal citation ratio (made): 0.02
# OJS-External citation ratio (made): 0.98
# OJS-Internal citation ratio (received): 0.03
# OJS-External citation ratio (received): 0.97
# Self-citation ratio: 0
# OJS-External citation ratio (made): 0.98
# OJS-Internal citation ratio (received): 0.03
# OJS-External citation ratio (received): 0.97
# Self-citation ratio: 0.03
# Network density: 0.0017
#
# Top 5 cited journals:
#   ISSN: 2278-4748
# 2278-4802, Citations: 2168
#   ISSN: 0140-6736
# 1474-547X, Citations: 573
#   ISSN: 0003-2999
# 1526-7598, Citations: 560
#   ISSN: 1745-3674
# 1745-3682, Citations: 499
#   ISSN: 0028-4793
# 1533-4406, Citations: 453
#
# Top 5 citing journals:
#   ISSN: 2278-4748
# 2278-4802, Citations: 2168
#   ISSN: 2277-8179, Citations: 140
#   ISSN: 2349-2562
# 2349-2570, Citations: 134
#   ISSN: 2168-8184, Citations: 133
#   ISSN: 2320-1770
# 2320-1789, Citations: 128
#
# ___________________________
#
# Analysis for Journal: Journal of Rehabilitation Medicine
# ISSN: 1650-1977
# 1651-2081
# Total nodes in network: 6126
# Total edges in network: 90876
# In-degree (citations received): 78335
# Out-degree (citations made): 15535
# Total degree: 93870
# OJS-Internal citations made: 54
# OJS-External citations made: 15481
# OJS-Internal citations received: 1073
# OJS-External citations received: 77262
# OJS-Internal citation ratio (made): 0.00
# OJS-External citation ratio (made): 1.00
# OJS-Internal citation ratio (received): 0.01
# OJS-External citation ratio (received): 0.99
# Self-citation ratio: 0.03
# Network density: 0.0024
#
# Top 5 cited journals:
#   ISSN: 1650-1977
# 1651-2081, Citations: 2994
#   ISSN: 0003-9993
# 1532-821X, Citations: 717
#   ISSN: 0963-8288
# 1464-5165, Citations: 411
#   ISSN: 0039-2499
# 1524-4628, Citations: 292
#   ISSN: 0269-2155
# 1477-0873, Citations: 264
#
# Top 5 citing journals:
#   ISSN: 1650-1977
# 1651-2081, Citations: 2994
#   ISSN: 0963-8288
# 1464-5165, Citations: 2914
#   ISSN: 0003-9993
# 1532-821X, Citations: 2204
#   ISSN: 1932-6203, Citations: 878
#   ISSN: 0269-2155
# 1477-0873, Citations: 876
#
# ___________________________
#
# Analysis for Journal: Biomolecules and Biomedicine
# ISSN: 2831-0896
# 2831-090X
# Total nodes in network: 5519
# Total edges in network: 42699
# In-degree (citations received): 13297
# Out-degree (citations made): 30910
# Total degree: 44207
# OJS-Internal citations made: 71
# OJS-External citations made: 30839
# OJS-Internal citations received: 140
# OJS-External citations received: 13157
# OJS-Internal citation ratio (made): 0.00
# OJS-External citation ratio (made): 1.00
# OJS-Internal citation ratio (received): 0.01
# OJS-External citation ratio (received): 0.99
# Self-citation ratio: 0.03
# Network density: 0.0014
#
# Top 5 cited journals:
#   ISSN: 2831-0896
# 2831-090X, Citations: 1508
#   ISSN: 0028-0836
# 1476-4687, Citations: 663
#   ISSN: 0036-8075
# 1095-9203, Citations: 379
#   ISSN: 0028-4793
# 1533-4406, Citations: 334
#   ISSN: 1932-6203, Citations: 298
#
# Top 5 citing journals:
#   ISSN: 2831-0896
# 2831-090X, Citations: 1508
#   ISSN: 1661-6596
# 1422-0067, Citations: 290
#   ISSN: 2045-2322, Citations: 122
#   ISSN: 1932-6203, Citations: 118
#   ISSN: 2072-6694, Citations: 118
#
# ___________________________
